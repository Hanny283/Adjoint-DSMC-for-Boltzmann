# %%
# %run runInflow.py
# Out:
# Geometry selftest passed.
# Open-channel drag minimisation (inflow left / outflow right / freestream top-bottom) -- exact adjoint
#   box 16.0x8.0  U0=1.0 T0=0.5 Kn=1.0  dt=0.1  window (0.0, 5.0] = steps 0..49  N_REF=1000000 (inflow 6568.3 particles/step, warm start T_WARM=60.0)  collisions=True
#   objective: drag + 1 x oint kappa^2 ds (= 6.3 at C_init, P0 = 6.283)   constraint: perimeter (L0 = 6.283, A0 = 3.142)
#   units: loss J/J(C_init) -> 1 and gradient/||g(C_init)|| -> 1 (independent factors; the optimiser uses the true slope kappa g.d);  first trial moves C by 0.05 x ||C_init|| = 0.0500   seeds 1->1   edge term reported only
# init: ||grad||=1.000e+00 -> init_step=5.000e-02 (first trial moves C by 0.05)
#    [472s] perimeter=6.283  seeds=1  ||g||/s.e.=inf  ||g||corr=nan (=nan% of initial)  F_x=24428.1  edge-term=0%
# iter   0: L=0.928393  ||grad||=1.1486e+00  step=0.075  alpha=0.05  |dC|=0.05
# ...
